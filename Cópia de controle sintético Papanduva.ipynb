# %%
#Import packages
import pandas as pd
from SyntheticControlMethods import Synth

#Import data
data = pd.read_csv("/Users/pedrocasqueira/Downloads/evolucao_Papanduva.csv")

# %%
print(data.head())
# Out:
#       Município   Ano      Agro  Indústria   Serviço       IPTU        ISS  \
# 0  Abelardo Luz  2003  4.189250   1.970634  4.305856  19.620344  22.493058
# 1  Abelardo Luz  2004  4.177702   1.893522  4.334912  13.000556  22.471249
# 2  Abelardo Luz  2005  3.337020   2.513031  4.313063  20.403954  24.207850
# 3  Abelardo Luz  2006  2.912158   2.075520  4.437517  13.436054  28.564528
# 4  Abelardo Luz  2007  4.303754   4.550658  6.727689  16.978015  31.884068
#
#         ITBI  Vínculos       PIB
# 0   8.641830  0.106188  12444.21
# 1  15.855838  0.114630  12575.91
# 2   9.761368  0.105703  12651.02
# 3  18.558990  0.096409  11981.64
# 4  15.156377  0.130188  20783.75

# %% [markdown]
# # sc é usada para PIB e scvinc para vínculos empregatícios

# %%
sc = Synth(data, "PIB", "Município", "Ano", 2009, "Papanduva", n_optim=100)

# %%
scvinc = Synth(data, "Vínculos", "Município", "Ano", 2009, "Papanduva", n_optim=50)

# %%
sc.plot(["original", "pointwise", "cumulative"], treated_label="Papanduva", 
            synth_label="Papanduva sintético", treatment_label="Concessão 2008")

# %%
scvinc.plot(["original", "pointwise", "cumulative"], treated_label="Papanduva", 
            synth_label="Papanduva sintético", treatment_label="Concessão 2008")

# %%
sc.original_data.weight_df
# Out:
#                   Weight
# Anchieta        0.124635
# Novo Horizonte  0.875365

# %%
scvinc.original_data.weight_df
# Out:
#             Weight
# Guaraciaba     1.0

# %%
sc.original_data.comparison_df
# Out:
#            Papanduva  Synthetic Papanduva     WMAPE  Importance
# Agro            2.95                 4.26      1.39        0.01
# Indústria       4.02                 1.09      2.93        0.37
# Serviço         3.38                 2.63      0.75        0.11
# IPTU           36.97                11.97     25.00        0.07
# ISS            37.48                18.27     19.21        0.01
# ITBI           14.75                22.52      9.11        0.26
# Vínculos        0.13                 0.06      0.07        0.03
# PIB         12795.30             12044.73  17728.91        0.13

# %%
scvinc.original_data.comparison_df
# Out:
#            Papanduva  Synthetic Papanduva     WMAPE  Importance
# Agro            2.95                 3.15      0.20        0.14
# Indústria       4.02                 1.88      2.14        0.24
# Serviço         3.38                 2.85      0.53        0.08
# IPTU           36.97                39.24      2.27        0.19
# ISS            37.48                37.91      0.43        0.06
# ITBI           14.75                10.57      4.18        0.01
# Vínculos        0.13                 0.12      0.00        0.22
# PIB         12795.30              2776.94  10018.36        0.06

# %%
sc.in_space_placebo(15)

# %%
scvinc.in_space_placebo(15)

# %%
#Visualize
sc.plot(['rmspe ratio'])

# %%
#Visualize
scvinc.plot(['rmspe ratio'])
