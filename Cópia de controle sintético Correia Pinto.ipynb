# %%
#Import packages
import pandas as pd
from SyntheticControlMethods import Synth

#Import data
data = pd.read_csv("/Users/pedrocasqueira/Downloads/evolucao_Correia Pinto.csv")

# %%
print(data.head())
# Out:
#       Município   Ano      Agro  Indústria   Serviço       IPTU        ISS  \
# 0  Abelardo Luz  2003  4.189250   1.970634  4.305856  19.620344  22.493058
# 1  Abelardo Luz  2004  4.177702   1.893522  4.334912  13.000556  22.471249
# 2  Abelardo Luz  2005  3.337020   2.513031  4.313063  20.403954  24.207850
# 3  Abelardo Luz  2006  2.912158   2.075520  4.437517  13.436054  28.564528
# 4  Abelardo Luz  2007  4.303754   4.550658  6.727689  16.978015  31.884068
#
#         ITBI  Vínculos       PIB
# 0   8.641830  0.106188  12444.21
# 1  15.855838  0.114630  12575.91
# 2   9.761368  0.105703  12651.02
# 3  18.558990  0.096409  11981.64
# 4  15.156377  0.130188  20783.75

# %% [markdown]
# # sc é usada para PIB e scvinc para vínculos empregatícios

# %%
sc = Synth(data, "PIB", "Município", "Ano", 2009, "Correia Pinto", n_optim=100)

# %%
scvinc = Synth(data, "Vínculos", "Município", "Ano", 2009, "Correia Pinto", n_optim=50)

# %%
sc.plot(["original", "pointwise", "cumulative"], treated_label="Correia Pinto",
            synth_label="Correia Pinto sintético", treatment_label="Concessão 2008")

# %%
scvinc.plot(["original", "pointwise", "cumulative"], treated_label="Correia Pinto",
            synth_label="Correia Pinto sintético", treatment_label="Concessão 2008")

# %%
sc.original_data.weight_df
# Out:
#         Weight
# Modelo     1.0

# %%
scvinc.original_data.weight_df
# Out:
#                 Weight
# Itapiranga    0.155243
# Sao Domingos  0.844757

# %%
sc.original_data.comparison_df
# Out:
#            Correia Pinto  Synthetic Correia Pinto    WMAPE  Importance
# Agro                1.18                     2.21     1.03        0.00
# Indústria           8.22                     5.19     3.03        0.21
# Serviço             2.70                     5.79     3.08        0.05
# IPTU               36.97                    45.31     8.34        0.26
# ISS               156.35                    28.78   127.57        0.04
# ITBI               14.44                    20.37     5.93        0.18
# Vínculos            0.18                     0.20     0.02        0.11
# PIB             15426.93                 16885.01  1458.08        0.16

# %%
scvinc.original_data.comparison_df
# Out:
#            Correia Pinto  Synthetic Correia Pinto     WMAPE  Importance
# Agro                1.18                     4.18      3.00        0.06
# Indústria           8.22                     3.29      4.94        0.46
# Serviço             2.70                     5.48      2.77        0.07
# IPTU               36.97                    51.60     14.63        0.14
# ISS               156.35                    88.89     67.46        0.08
# ITBI               14.44                    24.68     10.24        0.07
# Vínculos            0.18                     0.18      0.06        0.05
# PIB             15426.93                  3595.98  11830.95        0.07

# %%
sc.in_space_placebo(15)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  1.17656D+10    |proj g|=  8.75000D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9      1      2      9     0     9   0.000D+00   1.033D+09
#   F =   1032703848.7511998
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# ...

# %%
scvinc.in_space_placebo(15)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  4.33791D-03    |proj g|=  3.62911D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9      1      2      2     0     1   0.000D+00   2.936D-03
#   F =   2.9357321117973920E-003
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            9     M =           10
#
# ...

# %%
#Visualize
sc.plot(['rmspe ratio'])

# %%
#Visualize
scvinc.plot(['rmspe ratio'])
