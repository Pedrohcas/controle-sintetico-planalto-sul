# %%
#Import packages
import pandas as pd
from SyntheticControlMethods import Synth

#Import data
data = pd.read_csv("/Users/pedrocasqueira/Downloads/evolucao_Santa Cecilia.csv")

# %%
print(data.head())
# Out:
#       Município   Ano      Agro  Indústria   Serviço       IPTU        ISS  \
# 0  Abelardo Luz  2003  4.189250   1.970634  4.305856  19.620344  22.493058
# 1  Abelardo Luz  2004  4.177702   1.893522  4.334912  13.000556  22.471249
# 2  Abelardo Luz  2005  3.337020   2.513031  4.313063  20.403954  24.207850
# 3  Abelardo Luz  2006  2.912158   2.075520  4.437517  13.436054  28.564528
# 4  Abelardo Luz  2007  4.303754   4.550658  6.727689  16.978015  31.884068
#
#         ITBI  Vínculos       PIB
# 0   8.641830  0.106188  12444.21
# 1  15.855838  0.114630  12575.91
# 2   9.761368  0.105703  12651.02
# 3  18.558990  0.096409  11981.64
# 4  15.156377  0.130188  20783.75

# %% [markdown]
# # sc é usada para PIB e scvinc para vínculos empregatícios

# %%
sc = Synth(data, "PIB", "Município", "Ano", 2009, "Santa Cecilia", n_optim=100)

# %%
scvinc = Synth(data, "Vínculos", "Município", "Ano", 2009, "Santa Cecilia", n_optim=50)

# %%
sc.plot(["original", "pointwise", "cumulative"], treated_label="Santa Cecilia", 
            synth_label="Santa Cecilia sintético", treatment_label="Concessão 2008")

# %%
scvinc.plot(["original", "pointwise", "cumulative"], treated_label="Santa Cecilia", 
            synth_label="Santa Cecilia sintético", treatment_label="Concessão 2008")

# %%
sc.original_data.weight_df
# Out:
#                   Weight
# Novo Horizonte  0.886504
# Sao Domingos    0.113496

# %%
scvinc.original_data.weight_df
# Out:
#               Weight
# Sao Domingos     1.0

# %%
sc.original_data.comparison_df
# Out:
#            Santa Cecilia  Synthetic Santa Cecilia   WMAPE  Importance
# Agro                2.06                     4.46    2.40        0.13
# Indústria           2.63                     1.12    1.61        0.12
# Serviço             2.93                     2.86    0.62        0.12
# IPTU               57.35                    15.24   42.11        0.12
# ISS               116.23                    25.44   90.79        0.12
# ITBI               19.87                    24.61    4.74        0.13
# Vínculos            0.24                     0.07    0.17        0.12
# PIB              2373.33                  2399.12  262.17        0.13

# %%
scvinc.original_data.comparison_df
# Out:
#            Santa Cecilia  Synthetic Santa Cecilia    WMAPE  Importance
# Agro                2.06                     4.21     2.15        0.00
# Indústria           2.63                     3.09     0.47        0.11
# Serviço             2.93                     5.36     2.42        0.17
# IPTU               57.35                    53.77     3.58        0.24
# ISS               116.23                    94.20    22.03        0.24
# ITBI               19.87                    26.33     6.46        0.24
# Vínculos            0.24                     0.15     0.09        0.01
# PIB              2373.33                  3641.93  1268.61        0.00

# %%
sc.in_space_placebo(15)

# %%
scvinc.in_space_placebo(15)

# %%
#Visualize
sc.plot(['rmspe ratio'])

# %%
#Visualize
scvinc.plot(['rmspe ratio'])
